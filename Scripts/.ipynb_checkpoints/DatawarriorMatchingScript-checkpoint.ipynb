# %%
from openbabel import openbabel

# %%
from rdkit import Chem
from rdkit.Chem import rdBase
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Descriptors
from rdkit.Chem import Crippen

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as ss

# %%
def find_matches(library_set, test_set):
    canonical_library = pd.read_csv(library_set, sep='\t')
    canonical_test = pd.read_csv(test_set, sep='\t')
    print(1)
    
    library_codes = []
    for i in range(len(canonical_library['Canonical Code'])):
        library_codes.append(canonical_library['Canonical Code'][i])
    test_codes = []
    for i in range(len(canonical_test['Canonical Code'])):
        test_codes.append(canonical_test['Canonical Code'][i])
    print(2)
    
    matches = []
    for i in range(len(test_codes)):
        if test_codes[i] in library_codes:
            matches.append(test_codes[i])
    print(3)
    
    test_smiles = []
    test_generations = []
    library_smiles = [] 
    for i in range(len(matches)):
        for j in range(len(canonical_test['Canonical Code'])):
            if matches[i] == canonical_test['Canonical Code'][j]:
                test_smiles.append(canonical_test['Smiles'][j])
                test_generations.append(canonical_test['Generation'][j])
        for k in range(len(canonical_library['Canonical Code'])):
            if matches[i] == canonical_library['Canonical Code'][k]:
                library_smiles.append(canonical_library['Smiles'][k])
                break
    
    data = {'Generation': test_generations, 'Test Smiles': test_smiles, 'Library Smiles': library_smiles, 'Canonical Code': matches}
    df = pd.DataFrame(data)
    return(df)

# %%
# %%time
a = find_matches('./CHO_Data/Canonical_CHO.tsv', './GlucoseAmmData/Canonical_GlucoseAmm.tsv')
# Out:
# 1
# 2
# 3
# CPU times: user 9min 49s, sys: 705 ms, total: 9min 50s
# Wall time: 9min 52s

# %%
a.to_csv(r'GlucoseAmm_CHO.tsv', header=None, index=None, sep='\t', mode='a')

# %%
a
# Out:
#    Generation               Test Smiles                        Library Smiles  \
# 0          G3       C(CO)(CNCC(CO)=O)=O                C(=O)(CO[H])CNCC(=O)CO
# 1          G3       C(CN)(C(CO)(CO)O)=O            C(=O)(CN)[C@@](CO[H])(CO)O
# 2          G4     C(C(C=O)C(CN)(CN)O)=O     C(=O)C(C=O)[C@@](CN([H])[H])(CN)O
# 3          G4  C(C(CC(CN)(CN)O)=O)(O)=O   C(=O)(C(=O)O)C[C@](CN([H])[H])(CN)O
# 4          G4      C(CN)(CC(CN)(CN)O)=O      C(=O)(C[C@@](CN([H])[H])(CN)O)CN
# 5          G4      C(CN)(CC(CO)(CO)O)=O           C(=O)(C[C@@](CO[H])(CO)O)CN
# 6          G4     C(C(CC(CN)(CN)O)=O)=O      C(=O)C(=O)C[C@](CN([H])[H])(CN)O
# 7          G4          C(CN)(C(CO)CO)=O               C(=O)(CN)[C@H](CO[H])CO
# 8          G4      C(CO)(CC(CN)(CN)O)=O      C(=O)(C[C@@](CN([H])[H])(CN)O)CO
# 9          G4          C(CC(CN)(CN)O)=O          C(=O)C[C@@](CN([H])[H])(CN)O
# 10         G4      C(CO)(C(C(CO)=O)N)=O           C(=O)(CO[H])[C@H](C(=O)CO)N
# 11         G4       C(CNCC(CN)=O)(CO)=O           C(=O)(CN([H])[H])CNCC(=O)CO
# 12         G4        C(C)(C(CO)(CO)N)=O              C(=O)(C)[C@](CO[H])(CO)N
# 13         G4     C1(CNCC(C1(CO)O)=O)=O              C1(=O)CNCC(=O)C1(CO)O[H]
# 14         G4       C(C(CO)=O)(CNCCO)=O                C(=O)(C(=O)CNCCO)CO[H]
# 15         G4   C(CNCC(C(CO)=O)=O)(O)=O            C(=O)(C(=O)CO)CNCC(=O)O[H]
# 16         G4       C(C(CNCCO)=O)(CN)=O           C(=O)(C(=O)CNCCO)CN([H])[H]
# 17         G4   C(CNCC(C(CN)=O)=O)(O)=O            C(=O)(C(=O)CNCC(=O)O[H])CN
# 18         G4   C(CNCC(C(O)=O)=O)(CN)=O            C(=O)(C(=O)O[H])CNCC(=O)CN
# 19         G4       C(CNCC(CN)=O)(CN)=O           C(=O)(CN([H])[H])CNCC(=O)CN
# 20         G4           C(CNCCO)(CCO)=O                    C(=O)(CCO)CNCCO[H]
# 21         G4       C(CNCC(O)=O)(CCO)=O                C(=O)(CCO)CNCC(=O)O[H]
# 22         G4        C(C(CNCCO)=O)(O)=O                 C(=O)(C(=O)O[H])CNCCO
# 23         G4    C(CNCC(C(O)=O)=O)(O)=O             C(=O)(C(=O)O[H])CNCC(=O)O
# 24         G4       C(CC(CNCCO)=O)(O)=O                C(=O)(CC(=O)O[H])CNCCO
# 25         G4   C(CC(CNCC(O)=O)=O)(O)=O            C(=O)(CC(=O)O[H])CNCC(=O)O
# 26         G4            C(CNCCO)(CN)=O                C(=O)(CN([H])[H])CNCCO
# 27         G4        C(CNCC(CN)=O)(O)=O            C(=O)(CN([H])[H])CNCC(=O)O
# 28         G4          C=C(C(CNCCO)=O)N              C=C(C(=O)CNCCO)N([H])[H]
# 29         G4    C(CNCC(C(N)=C)=O)(O)=O          C=C(C(=O)CNCC(=O)O)N([H])[H]
# 30         G4      C(CN)(C(C(CN)=O)O)=O     C(=O)(CN([H])[H])[C@@H](C(=O)CN)O
# 31         G4  C(CN)(C(C(CN)=O)(CO)O)=O   C(=O)(CN([H])[H])[C@](C(=O)CN)(CO)O
# 32         G4            C(CO)(CNCCO)=O                     C(=O)(CO[H])CNCCO
# 33         G4        C(CNCC(CO)=O)(O)=O                 C(=O)(CNCC(=O)O[H])CO
# 34         G4   C(CO)(CNCC(C(O)=O)=O)=O            C(=O)(C(=O)O[H])CNCC(=O)CO
# 35         G4                C(C(CO)N)O                    C([C@@H](CO)N)O[H]
# 36         G4        C(CO)(CNC(CO)CO)=O            C(=O)(CN[C@@H](CO[H])CO)CO
# 37         G4            C(CNC(CO)CO)=O                C(=O)CN[C@@H](CO[H])CO
# 38         G4           C(CO)(CCNCCO)=O                    C(=O)(CCNCCO)CO[H]
# 39         G4       C(CNCCC(CO)=O)(O)=O                C(=O)(CCNCC(=O)O[H])CO
# 40         G4       C(CO)(C(CO)(CO)N)=O            C(=O)(CO)[C@@](CO[H])(CO)N
# 41         G4           C(C(CO)(CO)N)=O                C(=O)[C@@](CO[H])(CO)N
# 42         G4       C(C(CO)(CO)NCC=O)=O            C(=O)CN[C@@](C=O)(CO[H])CO
# 43         G4       C(CN)(C(CO)(CO)N)=O           C(=O)(CN)C(CO)(CO)N([H])[H]
# 44         G4  C(C(C=O)(C(CN)(CN)O)O)=O  C(=O)C(C=O)([C@@](CN([H])[H])(CN)O)O
# 45         G4     C(C(CN)=O)(C(CO)CO)=O          C(=O)(C(=O)[C@H](CO[H])CO)CN
# 46         G4     C(CN)(C(C(CN)=O)CO)=O    C(=O)(CN([H])[H])[C@@H](C(=O)CN)CO
# 47         G4           C(CN)(CCNCCO)=O               C(=O)(CCNCCO)CN([H])[H]
# 48         G4       C(CN)(CCNCC(O)=O)=O                C(=O)(CCNCC(=O)O[H])CN
# 49         G4       C(C(CCNCCO)=O)(O)=O                C(=O)(C(=O)O[H])CCNCCO
# 50         G4   C(CNCCC(C(O)=O)=O)(O)=O            C(=O)(C(=O)O[H])CCNCC(=O)O
# 51         G4           C(C(CO)(CCN)O)O                C(CN)[C@@](CO[H])(CO)O
# 52         G4                C(C(CN)N)N                    C(C(CN)N([H])[H])N
# 53         G4                C(C(CN)O)N               C([C@@H](CN)O)N([H])[H]
# 54         G4            C(CO)(CNCCN)=O                     C(=O)(CO[H])CNCCN
# 55         G4        C(CO)(CNC(CN)CN)=O       C(=O)(CN[C@@H](CN([H])[H])CN)CO
# 56         G4            C(CNC(CN)CN)=O            C(=O)CN[C@H](CN([H])[H])CN
# 57         G4            C(C(CO)(CN)O)O                  C([C@](CN)(CO)O)O[H]
# 58         G4           C(CO)(CCNCCN)=O               C(=O)(CCNCCN([H])[H])CO
# 59         G4          C(CC(CO)(CO)N)=O               C(=O)C[C@@](CO[H])(CO)N
#
#       Canonical Code
# 0   6664d6afe5949688
# 1   7996bac4feaaf65b
# 2   49ec96ee13d211fe
# 3   6886cd6bb1076a55
# 4   914cebd4b0ce287f
# 5   d93daa61acacfe90
# 6   5d30a1b78b8faf58
# 7    16d69721b96bddd
# 8   f8f14c4b07fa596f
# 9   5ed2be0e256a35fc
# 10  80d6eb93dcd08fe7
# 11  c908917571a8e8c1
# 12  bb87d784a2090912
# 13  5577ec4996b108d6
# 14  45f83184d1a4afac
# 15  45a0e84c5321754a
# 16  6da3804c0493f0f8
# 17  2ef5870fd7fc0b0d
# 18  75d39d4896427e5a
# 19  c5b5d25931fbd5bd
# 20  f88fe11c89c4a2ba
# 21  a43c18c2ade463c1
# 22  ce6e4add86a74c2d
# 23  7b81057994d73cf2
# 24  de6ed7ab43618e5b
# 25  b0f2b0f7ea96b6fc
# 26  18cfbd955ff12aad
# 27  69863c9f803632c6
# 28  4e35e871b92b47ae
# 29  14f0fd0450db6e84
# 30  37f633f434ecce4f
# 31  a81bf191cb8a3562
# 32  2877d9f7b06778e4
# 33   c5c36e003d5345b
# 34  4cbe35584820efe3
# 35  3fb577b857cc0830
# 36  95380c85e1bf239c
# 37  561aec0a8dff84d7
# 38  ada2dd1fa0e8266b
# 39  54f76d7ec440a57a
# 40  74ca4bbd265b9879
# 41   45ee45b47d11879
# 42  bb80da90d046d7e7
# 43  e78f7608cd60653b
# 44  b91be2fabac6fd63
# 45  869ad179455e5dc4
# 46  967a65c5e84a9bad
# 47  2883a41ea373c1e7
# 48  519a90cf5ff51281
# 49  280813ab515fd592
# 50  d3928551f012a646
# 51  1c6cde206fb85313
# 52  1f0ac6423cee0b2c
# 53  62608c108e0f0cb7
# 54  cbeb5bc807d51e0a
# 55  4e905f58aaa0b076
# 56  775cfb3c9a8822af
# 57  8f105d853b99c3ed
# 58  8e3af4e93478c663
# 59  f4d67411d2e5c610

# %%
def display(array):
    mols = []
    for i in range(len(array)):
        mol = Chem.MolFromSmiles(array[i])
        mols.append(mol)
    return(Draw.MolsToGridImage(mols, maxMols=100))

# %%
display(a['Test Smiles'])
